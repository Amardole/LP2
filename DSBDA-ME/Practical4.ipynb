# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("test.csv")
df
# Out:
#       ID     crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 1      6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 2      8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 3      9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 4     10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# ..   ...      ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 168  496  0.17899   0.0   9.69     0  0.585  5.670   28.8  2.7986    6  391
# 169  497  0.28960   0.0   9.69     0  0.585  5.390   72.9  2.7986    6  391
# 170  499  0.23912   0.0   9.69     0  0.585  6.019   65.3  2.4091    6  391
# 171  501  0.22438   0.0   9.69     0  0.585  6.027   79.7  2.4982    6  391
# 172  505  0.10959   0.0  11.93     0  0.573  6.794   89.3  2.3889    1  273
#
#      ptratio   black  lstat
# 0       17.8  392.83   4.03
# 1       18.7  394.12   5.21
# 2       15.2  396.90  19.15
# 3       15.2  386.63  29.93
# 4       15.2  386.71  17.10
# ..       ...     ...    ...
# 168     19.2  393.29  17.60
# 169     19.2  396.90  21.14
# 170     19.2  396.90  12.92
# 171     19.2  396.90  14.33
# 172     21.0  393.45   6.48
#
# [173 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat'],
#       dtype='object')

# %%
x = df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'black']]
y = df["lstat"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([10.9077024 , 14.41641975,  1.93715539,  3.73813307, 11.27471457,
#        18.90117303, 13.99916621, 13.69018544,  7.82742719, 15.05174999,
#        -1.18717188,  2.71555444, 12.49453078, 17.62997809,  0.22915142,
#        15.58063479, 11.16440578,  8.63612844, 11.51723795, 17.71759914,
#         3.14234492, 19.49162214, 17.9843901 ,  9.51578025, 12.23112352,
#        10.49678317, 28.74473777,  5.24065098, 11.2634732 , 31.84402158,
#         2.57304875, 18.65147216, 15.76136501, 23.77958776, 10.3249713 ,
#        19.66004539, 20.80255764, 17.73884104, 12.99160862, 12.81193735,
#         9.74193327,  3.82853002, 14.98430714, 11.23422498])

# %%
model.score(x_train,y_train)
# Out:
# 0.7629015985075667

# %%
model.score(x_test,y_test)
# Out:
# 0.5252339532922177

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 5.36014395749424
