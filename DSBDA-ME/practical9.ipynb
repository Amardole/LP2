# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=titanic, x='sex', y='age', hue='survived', palette='Set2')
plt.title('Distribution of Age by Gender and Survival Status')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
"""
Observations :

1. Females had a higher survival rate compared to males.
2. Most surviving females were younger (between ~20–40 years).
3. Male survivors were generally younger as well; older males had lower survival.
4. There are some outliers in age (very young and very old passengers).
5. Median age of non-surviving males was higher than that of surviving males.
"""
# Out:
# '\nObservations :\n\n1. Females had a higher survival rate compared to males.\n2. Most surviving females were younger (between ~20–40 years).\n3. Male survivors were generally younger as well; older males had lower survival.\n4. There are some outliers in age (very young and very old passengers).\n5. Median age of non-surviving males was higher than that of surviving males.\n'
